# %% [markdown]
# <a href="https://colab.research.google.com/github/ranganath-udayagiri/python-fundamentals/blob/main/day01-02-variables-and-dicts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ticket = {
    "id": 101,
    "customer": "Rangu",
    "is_urgent": True,
    "hours_open": 4.5
}

print(ticket)
print(ticket["customer"])
print(type(ticket))
# Out:
# {'id': 101, 'customer': 'Rangu', 'is_urgent': True, 'hours_open': 4.5}
# Rangu
# <class 'dict'>

# %%
print(ticket["id"])
print(ticket["hours_open"])

ticket["status"] = "open"          # adds a NEW field
ticket["hours_open"] = 6.0         # overwrites an existing one

print(ticket)
# Out:
# 101
# 4.5
# {'id': 101, 'customer': 'Rangu', 'is_urgent': True, 'hours_open': 6.0, 'status': 'open'}

# %%
print(ticket["customer_name"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_420/4188322187.py in <cell line: 0>()
# ----> 1 print(ticket["customer_name"])
#
# KeyError: 'customer_name'

# %%
print(ticket.get("customer_name"))
print(ticket.get("customer_name", "unknown"))
# Out:
# None
# unknown

# %%
ticket2 = {
    "id": 102,
    "customer": "kohli",
    "is_urgent": False,
    "hours_open": 5.0,
    "status": "open",
    "priority": "High"
}
print(ticket2["status"])
print(ticket2["priority"])
print(ticket2.get("hours_open", "over"))
# Out:
# open
# High
# 5.0
